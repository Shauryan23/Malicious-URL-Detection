# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('malicious_url_dataset.csv')
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Preview

# %%
dataset.head()
# Out:
#        URL  URL_LENGTH  NUMBER_SPECIAL_CHARACTERS WHOIS_COUNTRY  \
# 0   M0_109          16                          7          None
# 1  B0_2314          16                          6          None
# 2   B0_911          16                          6          None
# 3   B0_113          17                          6            US
# 4   B0_403          17                          6            US
#
#   WHOIS_STATEPRO     WHOIS_REGDATE WHOIS_UPDATED_DATE  Type
# 0           None  10-10-2015 18:21               None     1
# 1           None              None               None     0
# 2           None              None               None     0
# 3             AK  07-10-1997 04:00   12-09-2013 00:45     0
# 4             TX  12-05-1996 00:00   11-04-2017 00:00     0

# %%
print(X)
# Out:
# [[16 7 'None' 'None' '10-10-2015 18:21' 'None']
#  [16 6 'None' 'None' 'None' 'None']
#  [16 6 'None' 'None' 'None' 'None']
#  ...
#  [201 34 'US' 'FL' '15-02-1999 00:00' '15-07-2015 00:00']
#  [234 34 'US' 'CA' '01-04-1998 00:00' '09-12-2016 00:00']
#  [249 40 'US' 'Wisconsin' '14-11-2008 00:00' '20-11-2013 00:00']]

# %%
dataset.shape
# Out:
# (1781, 8)

# %%
dataset.dtypes
# Out:
# URL                          object
# URL_LENGTH                    int64
# NUMBER_SPECIAL_CHARACTERS     int64
# WHOIS_COUNTRY                object
# WHOIS_STATEPRO               object
# WHOIS_REGDATE                object
# WHOIS_UPDATED_DATE           object
# Type                          int64
# dtype: object

# %%
dataset.isnull().sum()
# Out:
# URL                          0
# URL_LENGTH                   0
# NUMBER_SPECIAL_CHARACTERS    0
# WHOIS_COUNTRY                0
# WHOIS_STATEPRO               0
# WHOIS_REGDATE                0
# WHOIS_UPDATED_DATE           0
# Type                         0
# dtype: int64

# %%
dataset['WHOIS_COUNTRY'].value_counts()
# Out:
# US                1103
# None               306
# CA                  84
# ES                  63
# AU                  35
# PA                  21
# GB                  19
# JP                  11
# UK                  10
# CN                  10
# IN                  10
# FR                   9
# CZ                   9
# CH                   6
# NL                   6
# [u'GB'; u'UK']       5
# KR                   5
# ru                   4
# AT                   4
# PH                   4
# BS                   4
# BE                   3
# KY                   3
# DE                   3
# HK                   3
# SC                   3
# SE                   3
# us                   3
# TR                   3
# NO                   2
# RU                   2
# IL                   2
# Cyprus               2
# KG                   2
# BR                   2
# SI                   2
# UY                   2
# UA                   2
# IT                   1
# LU                   1
# IE                   1
# AE                   1
# United Kingdom       1
# BY                   1
# TH                   1
# PK                   1
# se                   1
# LV                   1
# UG                   1
# Name: WHOIS_COUNTRY, dtype: int64

# %%
dataset['WHOIS_STATEPRO'].value_counts()
# Out:
# CA              372
# None            362
# NY               75
# WA               65
# Barcelona        62
#                ...
# bangkok           1
# kireka            1
# Peterborough      1
# Manitoba          1
# ME                1
# Name: WHOIS_STATEPRO, Length: 182, dtype: int64

# %%
dataset['WHOIS_REGDATE'].value_counts()
# Out:
# None                127
# 17-09-2008 00:00     62
# 13-01-2001 00:12     59
# 31-07-2000 00:00     47
# 15-02-2005 00:00     41
#                    ...
# 01-04-2008 22:47      1
# 30-05-2003 00:00      1
# 29-09-2015 00:00      1
# 15-06-2006 00:00      1
# 19-07-2010 00:00      1
# Name: WHOIS_REGDATE, Length: 891, dtype: int64

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ## Feature Scaling

# %%
# Scaling URL_LENGTH & NUMBER_SPECIAL_CHARACTERS

# Scaling X_train
X_train_features = X_train[:, 0:2]

scaler = StandardScaler().fit(X_train_features)
X_train_features = scaler.transform(X_train_features)

X_train[:, 0:2] = X_train_features

# Scaling X_test
X_test_features = X_test[:, 0:2]

scaler = StandardScaler().fit(X_test_features)
X_test_features = scaler.transform(X_test_features)

X_test[:, 0:2] = X_test_features
# Out:
# [[0.3744561528262324 0.6694074061611506 'US' 'Nevada' '13-11-2002 00:00'
#   '12-08-2015 00:00']
#  [0.51209409008128 0.21334167333761872 'Cyprus' 'None' '04-07-2007 00:00'
#   '22-02-2017 00:00']
#  [0.0647707940023753 0.21334167333761872 'US' 'FL' '19-03-1999 00:00'
#   '11-03-2012 00:00']
#  ...
#  [-0.7954663138416722 -0.47075692589767903 'GB' 'None' '09-03-2007 00:00'
#   '03-03-2015 00:00']
#  [0.8905984175326609 2.2656374710435117 'US' 'CO' '02-04-2009 00:00'
#   '21-03-2017 00:00']
#  [1.0626458391014706 1.1254731389846824 'US' 'va' '29-04-1994 00:00'
#   '30-08-2013 00:00']]
